# %%
import os
import random
import time
from typing import List, Tuple
from urllib.request import urlopen

import numpy as np
import scipy
import pandas as pd
import sklearn
import requests
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor

# %%
# !python --version
# Out:
# Python 3.8.5

# %%
import os
import random
import time
import json
from typing import Tuple
from urllib.request import urlopen

# ゲームサーバのアドレス
GAME_SERVER = os.getenv('GAME_SERVER', 'https://contest.2021-spring.gbc.tenka1.klab.jp')
# あなたのトークン
TOKEN = "b16c91e37d4c75777beba2eb755056fd"
# GameAPIを呼ぶ際のインターバル
GAME_INFO_SLEEP_TIME = 5000


def call_api(x: str) -> bytes:
    with urlopen(f'{GAME_SERVER}{x}') as res:
        return res.read()


def call_move(index: int, x: int, y: int) -> dict:
    res_str = call_api(f'/api/move/{TOKEN}/{index}-{x}-{y}')
    res_json = json.loads(res_str)
    return res_json


def call_move_next(index: int, x: int, y: int) -> dict:
    res_str = call_api(f'/api/move_next/{TOKEN}/{index}-{x}-{y}')
    res_json = json.loads(res_str)
    return res_json


def call_game() -> dict:
    res_str = call_api(f'/api/game/{TOKEN}')
    res_json = json.loads(res_str)
    return res_json


def call_master_data() -> dict:
    res_str = call_api(f'/api/master_data')
    res_json = json.loads(res_str)
    return res_json


class Bot:
    def __init__(self):
        self.move_histories = [["H", "O", "G", "E"] for _ in range(5)]

        self.master_data = call_master_data()
        self.game_info = call_game()
        self.start_game_time_ms = self.game_info['now']
        print("Start:", self.start_game_time_ms)
        self.start_time_ms = time.perf_counter_ns() // 1000000
        self.next_call_game_info_time_ms = self.get_now_game_time_ms() + GAME_INFO_SLEEP_TIME
        self.agent_move_finish_ms = [0] * self.master_data['num_agent']
        self.agent_move_point_queue = [[] for _ in range(self.master_data['num_agent'])]
        self.agent_last_point = [[] for _ in range(self.master_data['num_agent'])]
        for i in range(self.master_data['num_agent']):
            agent_move = self.game_info['agent'][i]['move']
            self.agent_last_point[i] = [agent_move[-1]['x'], agent_move[-1]['y']]
            self.set_move_point(i)

    # タスクを取得
    def choice_task(self, index: int) -> str:
        tasks = self.game_info['task'][42:]
        best_efficiency = 0
        best_task = ["Z"]
        for task1 in tasks:
            list_task1 = list(task1["s"])
            point = 1
            tim = 0
            if self.move_histories[index][-4:] == list_task1[:4]:
                list_task1 = list_task1[4:]
            elif self.move_histories[index][-3:] == list_task1[:3]:
                list_task1 = list_task1[3:]
            elif self.move_histories[index][-2:] == list_task1[:2]:
                list_task1 = list_task1[2:]
            elif self.move_histories[index][-1:] == list_task1[:1]:
                list_task1 = list_task1[1:]
            else:
                pass
            c = self.move_histories[index][-1]
            x, y = self.get_checkpoint(c)
            for next_c in list_task1:
                next_x, next_y = self.get_checkpoint(next_c)
                t = max(1.0, 0.1 * ((x-next_x)**2 + (y-next_y)**2)**0.5)
                tim += t

            efficiency = point / tim
            if best_efficiency < efficiency:
                best_efficiency = efficiency
                best_task = list_task1

        return "".join(best_task)

    def get_now_game_time_ms(self) -> int:
        now_ms = time.perf_counter_ns() // 1000000
        return self.start_game_time_ms + (now_ms - self.start_time_ms)

    def get_checkpoint(self, name: str) -> Tuple[int, int]:
        index = ord(name) - ord('A')
        checkpoint = self.master_data['checkpoints'][index]
        return checkpoint['x'], checkpoint['y']

    # 移動予定を設定
    def set_move_point(self, index: int):
        next_task = self.choice_task(index)
        print("Agent#{} next task:{}".format(index, next_task))
        for i in range(len(next_task)):
            before_x = self.agent_last_point[index][0]
            before_y = self.agent_last_point[index][1]
            move_x, move_y = self.get_checkpoint(next_task[i])

            # 移動先が同じ場所の場合判定が入らないため別の箇所に移動してからにする
            if move_x == before_x and move_y == before_y:
                tmp_x = (before_x-1) if before_x > 10 else (before_x+1)
                tmp_y = before_y
                self.agent_move_point_queue[index].append([tmp_x, tmp_y])

            self.agent_move_point_queue[index].append([move_x, move_y])
            self.move_histories[index].append(next_task[i])
            self.move_histories[index] = self.move_histories[index][1:]
            self.agent_last_point[index] = [move_x, move_y]

    def move_next(self, index: int) -> dict:
        move_next_point = self.agent_move_point_queue[index].pop(0)
        move_next_res = call_move_next(index+1, move_next_point[0], move_next_point[1])
        print("Agent#{} move_next to ({}, {})".format(index+1, move_next_point[0], move_next_point[1]))

        if move_next_res['status'] != 'ok':
            print(move_next_res)
            exit(1)

        assert len(move_next_res['move']) > 1

        self.agent_move_finish_ms[index] = move_next_res['move'][1]['t'] + 100

        # タスクを全てやりきったら次のタスクを取得
        if not self.agent_move_point_queue[index]:
            self.set_move_point(index)

        return move_next_res

    # game_infoの状態でのスコアを取得
    def get_now_score(self) -> float:
        score = 0.0
        tasks = self.game_info['task']
        for i in range(len(tasks)):
            if tasks[i]['total'] == 0:
                continue
            score += tasks[i]['weight'] * tasks[i]['count'] / tasks[i]['total']

        return score

    def solve(self):
        while True:
            now_game_time_ms = self.get_now_game_time_ms()

            # エージェントを移動させる
            for i in range(self.master_data['num_agent']):
                if self.agent_move_finish_ms[i] < now_game_time_ms:
                    move_next_res = self.move_next(i)
                    # 次の移動予定がない場合もう一度実行する
                    if len(move_next_res['move']) == 2:
                        self.move_next(i)

            # ゲーム情報更新
            if self.next_call_game_info_time_ms < now_game_time_ms:
                print('Update GameInfo')
                self.game_info = call_game()
                self.next_call_game_info_time_ms = self.get_now_game_time_ms() + GAME_INFO_SLEEP_TIME
                print("Score: {}".format(self.get_now_score()))

            time.sleep(0.5)

# %%
bot = Bot()
bot.solve()
# Out:
# Start: 7270954
# Agent#0 next task:CPUKE
# Agent#1 next task:CPUKE
# Agent#2 next task:CPUKE
# Agent#3 next task:CPUKE
# Agent#4 next task:CPUKE
# Agent#1 move_next to (17, 4)
# Agent#1 move_next to (21, 23)
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (17, 4)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (17, 4)
# Agent#4 move_next to (21, 23)
# Agent#5 move_next to (17, 4)
# Agent#5 move_next to (21, 23)
# Agent#1 move_next to (15, 19)
# Agent#5 move_next to (15, 19)
# Agent#2 move_next to (21, 23)
# Agent#3 move_next to (15, 19)
# Agent#4 move_next to (15, 19)
# Agent#1 move_next to (30, 6)
# Agent#2 move_next to (15, 19)
# Agent#5 move_next to (30, 6)
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Agent#2 move_next to (30, 6)
# Update GameInfo
# Score: 6109.209917759939
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (21, 23)
# Agent#1 move_next to (15, 19)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (21, 23)
# Agent#2 move_next to (17, 4)
# Agent#2 move_next to (21, 23)
# Agent#3 move_next to (15, 19)
# Agent#4 move_next to (15, 19)
# Agent#5 move_next to (15, 19)
# Agent#1 move_next to (30, 6)
# Agent#2 move_next to (15, 19)
# Agent#5 move_next to (30, 6)
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Update GameInfo
# Score: 6246.33848811063
# Agent#2 move_next to (30, 6)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (21, 23)
# Agent#1 move_next to (15, 19)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (21, 23)
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (15, 19)
# Agent#4 move_next to (15, 19)
# Agent#5 move_next to (15, 19)
# Agent#2 move_next to (21, 23)
# Agent#2 move_next to (15, 19)
# Agent#1 move_next to (30, 6)
# Agent#5 move_next to (30, 6)
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Update GameInfo
# Score: 6360.7872517528585
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Agent#2 move_next to (30, 6)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (21, 23)
# Agent#1 move_next to (15, 19)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (21, 23)
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (15, 19)
# Agent#5 move_next to (15, 19)
# Agent#2 move_next to (21, 23)
# Agent#4 move_next to (15, 19)
# Agent#1 move_next to (30, 6)
# Agent#2 move_next to (15, 19)
# Agent#5 move_next to (30, 6)
# Update GameInfo
# Score: 6455.879723062691
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Agent#2 move_next to (30, 6)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# Agent#1 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (21, 23)
# Agent#1 move_next to (15, 19)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (21, 23)
# Agent#2 move_next to (17, 4)
# Agent#5 move_next to (15, 19)
# Agent#2 move_next to (21, 23)
# Agent#3 move_next to (15, 19)
# Agent#4 move_next to (15, 19)
# Update GameInfo
# Score: 6512.396201831709
# Agent#1 move_next to (30, 6)
# Agent#2 move_next to (15, 19)
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#5 move_next to (30, 6)
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Agent#2 move_next to (30, 6)
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Agent#5 move_next to (21, 23)
# Agent#1 move_next to (15, 19)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (21, 23)
# Agent#2 move_next to (17, 4)
# Agent#5 move_next to (15, 19)
# Update GameInfo
# Score: 6526.4973075354965
# Agent#2 move_next to (21, 23)
# Agent#3 move_next to (15, 19)
# Agent#4 move_next to (15, 19)
# Agent#1 move_next to (30, 6)
# Agent#2 move_next to (15, 19)
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#5 move_next to (30, 6)
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Agent#2 move_next to (30, 6)
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (21, 23)
# Agent#5 move_next to (21, 23)
# Update GameInfo
# Score: 6530.747144861005
# Agent#1 move_next to (15, 19)
# Agent#2 move_next to (17, 4)
# Agent#5 move_next to (15, 19)
# Agent#2 move_next to (21, 23)
# Agent#3 move_next to (15, 19)
# Agent#4 move_next to (15, 19)
# Agent#1 move_next to (30, 6)
# Agent#2 move_next to (15, 19)
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#5 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Agent#2 move_next to (30, 6)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Update GameInfo
# Score: 6516.276442220476
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (17, 4)
# Agent#4 move_next to (21, 23)
# Agent#5 move_next to (21, 23)
# Agent#1 move_next to (15, 19)
# Agent#2 move_next to (17, 4)
# Agent#5 move_next to (15, 19)
# Agent#2 move_next to (21, 23)
# Agent#3 move_next to (15, 19)
# Agent#4 move_next to (15, 19)
# Agent#1 move_next to (30, 6)
# Agent#2 move_next to (15, 19)
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#5 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Agent#2 move_next to (30, 6)
# Update GameInfo
# Score: 6555.476911346659
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (21, 23)
# Agent#1 move_next to (15, 19)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (21, 23)
# Agent#2 move_next to (21, 23)
# Agent#3 move_next to (15, 19)
# Agent#4 move_next to (15, 19)
# Agent#5 move_next to (15, 19)
# Agent#1 move_next to (30, 6)
# Agent#2 move_next to (15, 19)
# Agent#1 move_next to (25, 9)
# Agent#0 next task:CPUKE
# Agent#3 move_next to (30, 6)
# Agent#5 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#5 move_next to (25, 9)
# Agent#4 next task:CPUKE
# Update GameInfo
# Score: 6599.683644501781
# Agent#3 move_next to (25, 9)
# Agent#2 next task:CPUKE
# Agent#4 move_next to (25, 9)
# Agent#3 next task:CPUKE
# Agent#2 move_next to (30, 6)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (25, 9)
# Agent#1 next task:CPUKE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-41230396c3bd> in <module>
#       1 bot = Bot()
# ----> 2 bot.solve()
#
# <ipython-input-24-c471ace32a7a> in solve(self)
#     172                 print("Score: {}".format(self.get_now_score()))
#     173
# --> 174             time.sleep(0.5)
#
# KeyboardInterrupt:

# %%
call_master_data()
# Out:
# {'game_period': 14400000,
#  'max_len_task': 10,
#  'num_agent': 5,
#  'checkpoints': [{'x': 12, 'y': 7},
#   {'x': 5, 'y': 24},
#   {'x': 17, 'y': 4},
#   {'x': 3, 'y': 20},
#   {'x': 25, 'y': 9},
#   {'x': 7, 'y': 5},
#   {'x': 28, 'y': 18},
#   {'x': 1, 'y': 10},
#   {'x': 24, 'y': 17},
#   {'x': 29, 'y': 30},
#   {'x': 30, 'y': 6},
#   {'x': 9, 'y': 29},
#   {'x': 3, 'y': 0},
#   {'x': 29, 'y': 13},
#   {'x': 12, 'y': 15},
#   {'x': 21, 'y': 23},
#   {'x': 15, 'y': 11},
#   {'x': 8, 'y': 16},
#   {'x': 0, 'y': 28},
#   {'x': 30, 'y': 27},
#   {'x': 15, 'y': 19},
#   {'x': 15, 'y': 24},
#   {'x': 11, 'y': 11},
#   {'x': 21, 'y': 0},
#   {'x': 0, 'y': 14},
#   {'x': 10, 'y': 20}],
#  'area_size': 30}

# %%
call_game()
# Out:
# {'status': 'ok',
#  'now': 7921853,
#  'agent': [{'move': [{'x': 1, 'y': 10, 't': 7921757},
#     {'x': 30, 'y': 27, 't': 7925119}],
#    'history': 'UOSPSXQCTH',
#    'history_times': [7903683,
#     7904183,
#     7905953,
#     7908112,
#     7910271,
#     7913771,
#     7915024,
#     7915753,
#     7918395,
#     7921757]},
#   {'move': [{'x': 29, 'y': 13, 't': 7919531},
#     {'x': 1, 'y': 10, 't': 7922348},
#     {'x': 10, 'y': 20, 't': 7923694}],
#    'history': 'DUVAIGTHKN',
#    'history_times': [7905589,
#     7906795,
#     7907710,
#     7909437,
#     7911000,
#     7911413,
#     7912533,
#     7915895,
#     7918823,
#     7919531]},
#   {'move': [{'x': 9, 'y': 29, 't': 7920675},
#     {'x': 29, 'y': 30, 't': 7922678},
#     {'x': 0, 'y': 14, 't': 7925991}],
#    'history': 'GXZGVBEZJL',
#    'history_times': [7903704,
#     7905636,
#     7907919,
#     7909731,
#     7911163,
#     7912163,
#     7914663,
#     7916524,
#     7918672,
#     7920675]},
#   {'move': [{'x': 17, 'y': 4, 't': 7920291},
#     {'x': 5, 'y': 24, 't': 7922624},
#     {'x': 15, 'y': 19, 't': 7923743}],
#    'history': 'HTCBUOSPSC',
#    'history_times': [7901305,
#     7904667,
#     7907309,
#     7909642,
#     7910761,
#     7911261,
#     7913031,
#     7915190,
#     7917349,
#     7920291]},
#   {'move': [{'x': 21, 'y': 23, 't': 7921617}, {'x': 9, 'y': 29, 't': 7922959}],
#    'history': 'KPAYPLIIYP',
#    'history_times': [7905276,
#     7907200,
#     7909036,
#     7910426,
#     7912711,
#     7914053,
#     7915974,
#     7916654,
#     7919073,
#     7921617]}],
#  'task': [{'s': 'K', 't': 0, 'weight': 1, 'count': 1281, 'total': 111051},
#   {'s': 'KLAB', 't': 0, 'weight': 100, 'count': 58, 'total': 4477},
#   {'s': 'GAME', 't': 0, 'weight': 100, 'count': 70, 'total': 3285},
#   {'s': 'BATTLE', 't': 0, 'weight': 100, 'count': 82, 'total': 3154},
#   {'s': 'CONTEST', 't': 0, 'weight': 100, 'count': 79, 'total': 3092},
#   {'s': 'GOOD', 't': 0, 'weight': 100, 'count': 62, 'total': 4367},
#   {'s': 'LUCK', 't': 0, 'weight': 100, 'count': 58, 'total': 3660},
#   {'s': 'AND', 't': 0, 'weight': 100, 'count': 71, 'total': 3784},
#   {'s': 'HAVE', 't': 0, 'weight': 100, 'count': 63, 'total': 3112},
#   {'s': 'FUN', 't': 0, 'weight': 100, 'count': 82, 'total': 4171},
#   {'s': 'UXACPMWUSK', 't': 0, 'weight': 100, 'count': 67, 'total': 3189},
#   {'s': 'EKVLDEJS', 't': 0, 'weight': 100, 'count': 69, 'total': 3077},
#   {'s': 'QKEOMSUNVH', 't': 600000, 'weight': 100, 'count': 44, 'total': 2678},
#   {'s': 'KJQTTU', 't': 600000, 'weight': 100, 'count': 42, 'total': 2584},
#   {'s': 'UNAGQCBQN', 't': 600000, 'weight': 100, 'count': 52, 'total': 2941},
#   {'s': 'KTAILJ', 't': 600000, 'weight': 100, 'count': 43, 'total': 2669},
#   {'s': 'TTUEBBFN', 't': 600000, 'weight': 100, 'count': 46, 'total': 2760},
#   {'s': 'QUWGKQS', 't': 600000, 'weight': 100, 'count': 48, 'total': 2764},
#   {'s': 'RXCFZTWBE', 't': 1200000, 'weight': 100, 'count': 36, 'total': 2115},
#   {'s': 'EQQAU', 't': 1200000, 'weight': 100, 'count': 42, 'total': 3189},
#   {'s': 'MUAOGAAPL', 't': 1200000, 'weight': 100, 'count': 31, 'total': 2109},
#   {'s': 'WBEFE', 't': 1200000, 'weight': 100, 'count': 23, 'total': 2309},
#   {'s': 'OGAAPLGJ', 't': 1200000, 'weight': 100, 'count': 34, 'total': 2178},
#   {'s': 'NAGQCBQN', 't': 1200000, 'weight': 100, 'count': 65, 'total': 4445},
#   {'s': 'GKQSWFU', 't': 1800000, 'weight': 100, 'count': 23, 'total': 1735},
#   {'s': 'OCDVCUFAB', 't': 1800000, 'weight': 100, 'count': 14, 'total': 1765},
#   {'s': 'LAIYLVQLF', 't': 1800000, 'weight': 100, 'count': 26, 'total': 1817},
#   {'s': 'LGJKWPC', 't': 1800000, 'weight': 100, 'count': 22, 'total': 1771},
#   {'s': 'KQSWFU', 't': 1800000, 'weight': 100, 'count': 50, 'total': 3384},
#   {'s': 'KINYJBCBU', 't': 1800000, 'weight': 100, 'count': 24, 'total': 1933},
#   {'s': 'VQLFEJR', 't': 2400000, 'weight': 100, 'count': 20, 'total': 1401},
#   {'s': 'TOVZWQKH', 't': 2400000, 'weight': 100, 'count': 8, 'total': 1408},
#   {'s': 'WBETILBF', 't': 2400000, 'weight': 100, 'count': 11, 'total': 1430},
#   {'s': 'YGZRACYQBI', 't': 2400000, 'weight': 100, 'count': 13, 'total': 1346},
#   {'s': 'NXUEFL', 't': 2400000, 'weight': 100, 'count': 15, 'total': 1398},
#   {'s': 'JEFPOJQL', 't': 2400000, 'weight': 100, 'count': 15, 'total': 1356},
#   {'s': 'PPRLHAZTH', 't': 3000000, 'weight': 100, 'count': 7, 'total': 1309},
#   {'s': 'QSWFUV', 't': 3000000, 'weight': 100, 'count': 8, 'total': 1777},
#   {'s': 'WDPQJH', 't': 3000000, 'weight': 100, 'count': 3, 'total': 1451},
#   {'s': 'PMWUSKDDS', 't': 3000000, 'weight': 100, 'count': 7, 'total': 1308},
#   {'s': 'ZTWBEZIKMB', 't': 3000000, 'weight': 100, 'count': 4, 'total': 1304},
#   {'s': 'YHTDDUVA', 't': 3000000, 'weight': 100, 'count': 4, 'total': 2122},
#   {'s': 'GKQSQF', 't': 3600000, 'weight': 10000, 'count': 89, 'total': 3775},
#   {'s': 'BETILBF', 't': 3600000, 'weight': 10000, 'count': 68, 'total': 3022},
#   {'s': 'BFJIOF', 't': 3600000, 'weight': 10000, 'count': 86, 'total': 2941},
#   {'s': 'VWJQZBVMQD',
#    't': 3600000,
#    'weight': 10000,
#    'count': 103,
#    'total': 2113},
#   {'s': 'GCMAQGJLOP',
#    't': 3600000,
#    'weight': 10000,
#    'count': 77,
#    'total': 2276},
#   {'s': 'CJQVABWF', 't': 3600000, 'weight': 10000, 'count': 90, 'total': 2373},
#   {'s': 'YHAUAWE', 't': 4200000, 'weight': 10000, 'count': 51, 'total': 3564},
#   {'s': 'BYWGVB', 't': 4200000, 'weight': 10000, 'count': 54, 'total': 3954},
#   {'s': 'BFQUHOOTI',
#    't': 4200000,
#    'weight': 10000,
#    'count': 52,
#    'total': 2257},
#   {'s': 'IKIJUVQYTC',
#    't': 4200000,
#    'weight': 10000,
#    'count': 69,
#    'total': 1767},
#   {'s': 'ILJKIIMKOQ',
#    't': 4200000,
#    'weight': 10000,
#    'count': 59,
#    'total': 1695},
#   {'s': 'NYYLN', 't': 4200000, 'weight': 10000, 'count': 54, 'total': 4917},
#   {'s': 'TRIWGZUAA',
#    't': 4800000,
#    'weight': 10000,
#    'count': 37,
#    'total': 2141},
#   {'s': 'GQCBQNENCB',
#    't': 4800000,
#    'weight': 10000,
#    'count': 47,
#    'total': 1789},
#   {'s': 'MQXLGKBJ', 't': 4800000, 'weight': 10000, 'count': 25, 'total': 1748},
#   {'s': 'BHQNJ', 't': 4800000, 'weight': 10000, 'count': 37, 'total': 3569},
#   {'s': 'QZBVMQDAFX',
#    't': 4800000,
#    'weight': 10000,
#    'count': 42,
#    'total': 1948},
#   {'s': 'HAZDIAIE', 't': 4800000, 'weight': 10000, 'count': 28, 'total': 2295},
#   {'s': 'QZDOULC', 't': 5400000, 'weight': 10000, 'count': 26, 'total': 3264},
#   {'s': 'HTDDUVA', 't': 5400000, 'weight': 10000, 'count': 11, 'total': 2235},
#   {'s': 'WFUWWKBFWW',
#    't': 5400000,
#    'weight': 10000,
#    'count': 21,
#    'total': 2443},
#   {'s': 'ZKDGNRXK', 't': 5400000, 'weight': 10000, 'count': 20, 'total': 1689},
#   {'s': 'EPKFVY', 't': 5400000, 'weight': 10000, 'count': 26, 'total': 2356},
#   {'s': 'INKKLX', 't': 5400000, 'weight': 10000, 'count': 20, 'total': 2848},
#   {'s': 'LKRZHFXQDB',
#    't': 6000000,
#    'weight': 10000,
#    'count': 18,
#    'total': 1772},
#   {'s': 'RNNSCLKKGO',
#    't': 6000000,
#    'weight': 10000,
#    'count': 2,
#    'total': 1621},
#   {'s': 'SKPGZVBY', 't': 6000000, 'weight': 10000, 'count': 7, 'total': 2070},
#   {'s': 'DUVAWJGDU',
#    't': 6000000,
#    'weight': 10000,
#    'count': 12,
#    'total': 1934},
#   {'s': 'OEDDCQDCK',
#    't': 6000000,
#    'weight': 10000,
#    'count': 13,
#    'total': 1841},
#   {'s': 'KPDVGB', 't': 6000000, 'weight': 10000, 'count': 17, 'total': 2436},
#   {'s': 'EKAHDBB', 't': 6600000, 'weight': 10000, 'count': 9, 'total': 4383},
#   {'s': 'YGUFHRDM', 't': 6600000, 'weight': 10000, 'count': 9, 'total': 2106},
#   {'s': 'IEUBSC', 't': 6600000, 'weight': 10000, 'count': 10, 'total': 3040},
#   {'s': 'BAYQHW', 't': 6600000, 'weight': 10000, 'count': 79, 'total': 3085},
#   {'s': 'HYLYJPLYZH',
#    't': 6600000,
#    'weight': 10000,
#    'count': 7,
#    'total': 1736},
#   {'s': 'CUXVM', 't': 6600000, 'weight': 10000, 'count': 88, 'total': 2986},
#   {'s': 'CPUKE', 't': 7200000, 'weight': 10000, 'count': 94, 'total': 3968},
#   {'s': 'DWLBVWNSK',
#    't': 7200000,
#    'weight': 10000,
#    'count': 13,
#    'total': 1686},
#   {'s': 'CBUOSPS', 't': 7200000, 'weight': 10000, 'count': 22, 'total': 2125},
#   {'s': 'NIJSHNU', 't': 7200000, 'weight': 10000, 'count': 21, 'total': 1933},
#   {'s': 'QCBQNKM', 't': 7200000, 'weight': 10000, 'count': 38, 'total': 2196},
#   {'s': 'YPLII', 't': 7200000, 'weight': 10000, 'count': 47, 'total': 3545},
#   {'s': 'THKNHZKPA', 't': 7800000, 'weight': 10000, 'count': 3, 'total': 222},
#   {'s': 'WGXZGV', 't': 7800000, 'weight': 10000, 'count': 8, 'total': 464},
#   {'s': 'ZVMCTWWA', 't': 7800000, 'weight': 10000, 'count': 1, 'total': 329},
#   {'s': 'TDDUVAIG', 't': 7800000, 'weight': 10000, 'count': 1, 'total': 566},
#   {'s': 'BEZJLJ', 't': 7800000, 'weight': 10000, 'count': 9, 'total': 331},
#   {'s': 'XQCTHT', 't': 7800000, 'weight': 10000, 'count': 4, 'total': 406}],
#  'next_task': 8400000}

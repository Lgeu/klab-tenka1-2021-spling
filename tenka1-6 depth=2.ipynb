# %%
import os
import random
import time
from typing import List, Tuple
from urllib.request import urlopen

import numpy as np
import scipy
import pandas as pd
import sklearn
import requests
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor

# %%
import os
import random
import time
import json
from typing import Tuple
from urllib.request import urlopen

# ゲームサーバのアドレス
GAME_SERVER = os.getenv('GAME_SERVER', 'https://contest.2021-spring.gbc.tenka1.klab.jp')
# あなたのトークン
TOKEN = "b16c91e37d4c75777beba2eb755056fd"
# GameAPIを呼ぶ際のインターバル
GAME_INFO_SLEEP_TIME = 5000


def call_api(x: str) -> bytes:
    with urlopen(f'{GAME_SERVER}{x}') as res:
        return res.read()


def call_move(index: int, x: int, y: int) -> dict:
    res_str = call_api(f'/api/move/{TOKEN}/{index}-{x}-{y}')
    res_json = json.loads(res_str)
    return res_json


def call_move_next(index: int, x: int, y: int) -> dict:
    res_str = call_api(f'/api/move_next/{TOKEN}/{index}-{x}-{y}')
    res_json = json.loads(res_str)
    return res_json


def call_game() -> dict:
    res_str = call_api(f'/api/game/{TOKEN}')
    res_json = json.loads(res_str)
    return res_json


def call_master_data() -> dict:
    res_str = call_api(f'/api/master_data')
    res_json = json.loads(res_str)
    return res_json


class Bot:
    def __init__(self):
        self.move_histories = [["H", "O", "G", "E"] for _ in range(5)]

        self.master_data = call_master_data()
        self.game_info = call_game()
        self.start_game_time_ms = self.game_info['now']
        print("Start:", self.start_game_time_ms)
        self.start_time_ms = time.perf_counter_ns() // 1000000
        self.next_call_game_info_time_ms = self.get_now_game_time_ms() + GAME_INFO_SLEEP_TIME
        self.agent_move_finish_ms = [0] * self.master_data['num_agent']
        self.agent_move_point_queue = [[] for _ in range(self.master_data['num_agent'])]
        self.agent_last_point = [[] for _ in range(self.master_data['num_agent'])]
        for i in range(self.master_data['num_agent']):
            agent_move = self.game_info['agent'][i]['move']
            self.agent_last_point[i] = [agent_move[-1]['x'], agent_move[-1]['y']]
            self.set_move_point(i)

    # タスクを取得
    def choice_task(self, index: int) -> str:
        tasks = self.game_info['task'][42:]
        best_efficiency = 0
        best_task = ["Z"]
        for task1 in tasks:
            list_task1 = list(task1["s"])
            if random.random() < 0.5 and len(list_task1)==5:
                continue
            point1 = (1.0 / (task1["total"] + 1.0)) ** 1.0
            tim1 = 0
            if self.move_histories[index][-4:] == list_task1[:4]:
                list_task1 = list_task1[4:]
            elif self.move_histories[index][-3:] == list_task1[:3]:
                list_task1 = list_task1[3:]
            elif self.move_histories[index][-2:] == list_task1[:2]:
                list_task1 = list_task1[2:]
            elif self.move_histories[index][-1:] == list_task1[:1]:
                list_task1 = list_task1[1:]
            else:
                pass
            c = self.move_histories[index][-1]
            x, y = self.get_checkpoint(c)
            for next_c in list_task1:
                next_x, next_y = self.get_checkpoint(next_c)
                t = max(0.5, 0.1 * ((x-next_x)**2 + (y-next_y)**2)**0.5)
                tim1 += t
            
            # efficiency = point / tim
            # if best_efficiency < efficiency:
            #     best_efficiency = efficiency
            #     best_task = list_task1

            self.move_histories[index] += list_task1
            for task2 in tasks:
                list_task2 = list(task2["s"])
                point12 = point1 + (1.0 / (task2["total"] + 1.0)) ** 1.0
                tim12 = tim1
                if self.move_histories[index][-4:] == list_task2[:4]:
                    list_task2 = list_task2[4:]
                elif self.move_histories[index][-3:] == list_task2[:3]:
                    list_task2 = list_task2[3:]
                elif self.move_histories[index][-2:] == list_task2[:2]:
                    list_task2 = list_task2[2:]
                elif self.move_histories[index][-1:] == list_task2[:1]:
                    list_task2 = list_task2[1:]
                else:
                    pass
                c = self.move_histories[index][-1]
                x, y = self.get_checkpoint(c)
                for next_c in list_task2:
                    next_x, next_y = self.get_checkpoint(next_c)
                    t = max(1.0, 0.1*((x-next_x)**2+(y-next_y)**2)**0.5)
                    tim12 += t
                efficiency = point12 / tim12
                if best_efficiency < efficiency:
                    best_efficiency = efficiency
                    best_task = list_task1
            for _ in list_task1:
                self.move_histories[index].pop()
                
        if random.random() < 0.03:
            best_task = list(random.choice(tasks)["s"])
        return "".join(best_task)

    def get_now_game_time_ms(self) -> int:
        now_ms = time.perf_counter_ns() // 1000000
        return self.start_game_time_ms + (now_ms - self.start_time_ms)

    def get_checkpoint(self, name: str) -> Tuple[int, int]:
        index = ord(name) - ord('A')
        checkpoint = self.master_data['checkpoints'][index]
        return checkpoint['x'], checkpoint['y']

    # 移動予定を設定
    def set_move_point(self, index: int):
        next_task = self.choice_task(index)
        print("Agent#{} next task:{}".format(index, next_task))
        for i in range(len(next_task)):
            before_x = self.agent_last_point[index][0]
            before_y = self.agent_last_point[index][1]
            move_x, move_y = self.get_checkpoint(next_task[i])

            # 移動先が同じ場所の場合判定が入らないため別の箇所に移動してからにする
            if move_x == before_x and move_y == before_y:
                tmp_x = (before_x-1) if before_x > 10 else (before_x+1)
                tmp_y = before_y
                self.agent_move_point_queue[index].append([tmp_x, tmp_y])

            self.agent_move_point_queue[index].append([move_x, move_y])
            self.move_histories[index].append(next_task[i])
            self.move_histories[index] = self.move_histories[index][1:]
            self.agent_last_point[index] = [move_x, move_y]

    def move_next(self, index: int) -> dict:
        move_next_point = self.agent_move_point_queue[index].pop(0)
        move_next_res = call_move_next(index+1, move_next_point[0], move_next_point[1])
        print("Agent#{} move_next to ({}, {})".format(index+1, move_next_point[0], move_next_point[1]))

        if move_next_res['status'] != 'ok':
            print(move_next_res)
            exit(1)

        assert len(move_next_res['move']) > 1

        self.agent_move_finish_ms[index] = move_next_res['move'][1]['t'] + 100

        # タスクを全てやりきったら次のタスクを取得
        if not self.agent_move_point_queue[index]:
            self.set_move_point(index)

        return move_next_res

    # game_infoの状態でのスコアを取得
    def get_now_score(self) -> float:
        score = 0.0
        tasks = self.game_info['task']
        for i in range(len(tasks)):
            if tasks[i]['total'] == 0:
                continue
            score += tasks[i]['weight'] * tasks[i]['count'] / tasks[i]['total']

        return score

    def solve(self):
        while True:
            now_game_time_ms = self.get_now_game_time_ms()

            # エージェントを移動させる
            for i in range(self.master_data['num_agent']):
                if self.agent_move_finish_ms[i] < now_game_time_ms:
                    move_next_res = self.move_next(i)
                    # 次の移動予定がない場合もう一度実行する
                    if len(move_next_res['move']) == 2:
                        self.move_next(i)

            # ゲーム情報更新
            if self.next_call_game_info_time_ms < now_game_time_ms:
                print('Update GameInfo')
                self.game_info = call_game()
                self.next_call_game_info_time_ms = self.get_now_game_time_ms() + GAME_INFO_SLEEP_TIME
                print("Score: {}".format(self.get_now_score()))

            time.sleep(0.5)

# %%
bot = Bot()
bot.solve()
# Out:
# Start: 10337832
# Agent#0 next task:IIMKOQNJA
# Agent#1 next task:IIMKOQNJA
# Agent#2 next task:IIMKOQNJA
# Agent#3 next task:IIMKOQNJA
# Agent#4 next task:IIMKOQNJA
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (24, 17)
# Agent#4 move_next to (23, 17)
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (23, 17)
# Agent#3 move_next to (23, 17)
# Agent#5 move_next to (23, 17)
# Agent#1 move_next to (24, 17)
# Agent#1 move_next to (3, 0)
# Agent#4 move_next to (24, 17)
# Agent#4 move_next to (3, 0)
# Agent#2 move_next to (23, 17)
# Agent#3 move_next to (24, 17)
# Agent#3 move_next to (3, 0)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#2 move_next to (24, 17)
# Agent#2 move_next to (3, 0)
# Agent#1 move_next to (30, 6)
# Agent#1 move_next to (12, 15)
# Agent#4 move_next to (30, 6)
# Agent#4 move_next to (12, 15)
# Update GameInfo
# Score: 10949.210410753183
# Agent#3 move_next to (30, 6)
# Agent#3 move_next to (12, 15)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (30, 6)
# Agent#2 move_next to (12, 15)
# Agent#1 move_next to (15, 11)
# Agent#4 move_next to (15, 11)
# Agent#3 move_next to (15, 11)
# Agent#5 move_next to (15, 11)
# Agent#1 move_next to (29, 13)
# Agent#2 move_next to (15, 11)
# Agent#4 move_next to (29, 13)
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (29, 13)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (29, 13)
# Update GameInfo
# Score: 10926.119515026618
# Agent#3 move_next to (29, 30)
# Agent#5 move_next to (29, 30)
# Agent#1 move_next to (12, 7)
# Agent#0 next task:MSPFVQYXKS
# Agent#2 move_next to (29, 13)
# Agent#4 move_next to (12, 7)
# Agent#3 next task:MSPFVQYXKS
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (12, 7)
# Agent#2 next task:MSPFVQYXKS
# Agent#5 move_next to (12, 7)
# Agent#4 next task:MSPFVQYXKS
# Agent#1 move_next to (3, 0)
# Agent#2 move_next to (12, 7)
# Agent#1 next task:MSPFVQYXKS
# Agent#4 move_next to (3, 0)
# Agent#3 move_next to (3, 0)
# Agent#5 move_next to (3, 0)
# Agent#2 move_next to (3, 0)
# Update GameInfo
# Score: 10908.76447195545
# Agent#1 move_next to (0, 28)
# Agent#4 move_next to (0, 28)
# Agent#1 move_next to (21, 23)
# Agent#3 move_next to (0, 28)
# Agent#5 move_next to (0, 28)
# Agent#4 move_next to (21, 23)
# Agent#2 move_next to (0, 28)
# Agent#3 move_next to (21, 23)
# Agent#5 move_next to (21, 23)
# Agent#2 move_next to (21, 23)
# Agent#1 move_next to (7, 5)
# Agent#4 move_next to (7, 5)
# Agent#3 move_next to (7, 5)
# Agent#5 move_next to (7, 5)
# Update GameInfo
# Score: 11012.695531274008
# Agent#2 move_next to (7, 5)
# Agent#1 move_next to (15, 24)
# Agent#4 move_next to (15, 24)
# Agent#3 move_next to (15, 24)
# Agent#5 move_next to (15, 24)
# Agent#2 move_next to (15, 24)
# Agent#1 move_next to (15, 11)
# Agent#4 move_next to (15, 11)
# Agent#3 move_next to (15, 11)
# Agent#5 move_next to (15, 11)
# Update GameInfo
# Score: 10994.896558361834
# Agent#1 move_next to (0, 14)
# Agent#2 move_next to (15, 11)
# Agent#4 move_next to (0, 14)
# Agent#3 move_next to (0, 14)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (21, 0)
# Agent#4 move_next to (21, 0)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (21, 0)
# Agent#5 move_next to (21, 0)
# Agent#1 move_next to (30, 6)
# Agent#4 move_next to (30, 6)
# Agent#2 move_next to (21, 0)
# Agent#3 move_next to (30, 6)
# Agent#5 move_next to (30, 6)
# Agent#2 move_next to (30, 6)
# Update GameInfo
# Score: 11006.060938057104
# Agent#1 move_next to (0, 28)
# Agent#0 next task:RLYCV
# Agent#4 move_next to (0, 28)
# Agent#3 next task:RLYCV
# Agent#1 move_next to (8, 16)
# Agent#3 move_next to (0, 28)
# Agent#2 next task:RLYCV
# Agent#5 move_next to (0, 28)
# Agent#4 next task:RLYCV
# Agent#4 move_next to (8, 16)
# Agent#2 move_next to (0, 28)
# Agent#1 next task:RLYCV
# Agent#3 move_next to (8, 16)
# Agent#5 move_next to (8, 16)
# Agent#2 move_next to (8, 16)
# Agent#1 move_next to (9, 29)
# Agent#4 move_next to (9, 29)
# Update GameInfo
# Score: 11041.33647382197
# Agent#3 move_next to (9, 29)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (0, 14)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IIMKOQNJA
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IIMKOQNJA
# Update GameInfo
# Score: 11069.670908279768
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IIMKOQNJA
# Agent#4 move_next to (24, 17)
# Agent#3 move_next to (24, 17)
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (23, 17)
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (24, 17)
# Agent#1 move_next to (3, 0)
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (23, 17)
# Agent#4 move_next to (29, 30)
# Agent#2 move_next to (23, 17)
# Agent#3 move_next to (29, 30)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#4 move_next to (12, 15)
# Update GameInfo
# Score: 11098.55665330175
# Agent#2 move_next to (24, 17)
# Agent#2 move_next to (3, 0)
# Agent#3 move_next to (12, 15)
# Agent#1 move_next to (30, 6)
# Agent#1 move_next to (12, 15)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IIMKOQNJA
# Agent#2 move_next to (30, 6)
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IIMKOQNJA
# Agent#1 move_next to (15, 11)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (15, 11)
# Update GameInfo
# Score: 11068.425184930202
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (23, 17)
# Agent#1 move_next to (29, 13)
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (15, 11)
# Agent#3 move_next to (23, 17)
# Agent#4 move_next to (24, 17)
# Agent#4 move_next to (3, 0)
# Agent#5 move_next to (29, 13)
# Agent#5 move_next to (29, 30)
# Agent#1 move_next to (12, 7)
# Agent#0 next task:IIMKOQNJA
# Agent#3 move_next to (24, 17)
# Agent#3 move_next to (3, 0)
# Agent#2 move_next to (29, 13)
# Agent#2 move_next to (29, 30)
# Agent#5 move_next to (12, 7)
# Agent#4 next task:IIMKOQNJA
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (12, 7)
# Agent#1 next task:IIMKOQNJA
# Agent#4 move_next to (30, 6)
# Agent#4 move_next to (12, 15)
# Update GameInfo
# Score: 11052.826601642
# Agent#3 move_next to (30, 6)
# Agent#3 move_next to (12, 15)
# Agent#5 move_next to (24, 17)
# Agent#2 move_next to (24, 17)
# Agent#1 move_next to (23, 17)
# Agent#4 move_next to (15, 11)
# Agent#5 move_next to (23, 17)
# Agent#1 move_next to (24, 17)
# Agent#1 move_next to (3, 0)
# Agent#3 move_next to (15, 11)
# Agent#2 move_next to (23, 17)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#4 move_next to (29, 13)
# Update GameInfo
# Score: 11087.885157558616
# Agent#3 move_next to (29, 13)
# Agent#4 move_next to (29, 30)
# Agent#2 move_next to (24, 17)
# Agent#2 move_next to (3, 0)
# Agent#3 move_next to (29, 30)
# Agent#1 move_next to (30, 6)
# Agent#1 move_next to (12, 15)
# Agent#4 move_next to (12, 7)
# Agent#3 next task:IIMKOQNJA
# Agent#3 move_next to (12, 7)
# Agent#2 next task:IIMKOQNJA
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Agent#4 move_next to (24, 17)
# Agent#2 move_next to (30, 6)
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (24, 17)
# Agent#1 move_next to (15, 11)
# Update GameInfo
# Score: 11059.64589023602
# Agent#5 move_next to (15, 11)
# Agent#4 move_next to (23, 17)
# Agent#1 move_next to (29, 13)
# Agent#3 move_next to (23, 17)
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (15, 11)
# Agent#5 move_next to (29, 13)
# Agent#4 move_next to (24, 17)
# Agent#4 move_next to (3, 0)
# Agent#5 move_next to (29, 30)
# Agent#1 move_next to (12, 7)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (24, 17)
# Agent#3 move_next to (3, 0)
# Agent#2 move_next to (29, 13)
# Agent#2 move_next to (29, 30)
# Agent#5 move_next to (12, 7)
# Agent#4 next task:IAJOV
# Agent#1 move_next to (24, 17)
# Update GameInfo
# Score: 11067.199844299059
# Agent#2 move_next to (12, 7)
# Agent#1 next task:IAJOV
# Agent#4 move_next to (30, 6)
# Agent#4 move_next to (12, 15)
# Agent#5 move_next to (24, 17)
# Agent#3 move_next to (30, 6)
# Agent#3 move_next to (12, 15)
# Agent#2 move_next to (24, 17)
# Agent#1 move_next to (12, 7)
# Agent#5 move_next to (12, 7)
# Agent#4 move_next to (15, 11)
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (15, 11)
# Agent#2 move_next to (12, 7)
# Agent#5 move_next to (29, 30)
# Agent#1 move_next to (12, 15)
# Agent#4 move_next to (29, 13)
# Update GameInfo
# Score: 11096.887390802585
# Agent#4 move_next to (29, 30)
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (29, 13)
# Agent#3 move_next to (29, 30)
# Agent#5 move_next to (12, 15)
# Agent#4 move_next to (12, 7)
# Agent#3 next task:SRLYCV
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (12, 7)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IAJOV
# Agent#3 move_next to (0, 28)
# Agent#1 move_next to (24, 17)
# Update GameInfo
# Score: 11075.85782754759
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#1 move_next to (12, 7)
# Agent#5 move_next to (24, 17)
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (8, 16)
# Agent#2 move_next to (24, 17)
# Agent#5 move_next to (29, 30)
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (12, 7)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (0, 14)
# Update GameInfo
# Score: 11098.306159300793
# Agent#3 move_next to (0, 14)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (17, 4)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IAJOV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#1 move_next to (12, 7)
# Agent#5 move_next to (24, 17)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (12, 7)
# Update GameInfo
# Score: 11092.990237297765
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (0, 28)
# Agent#2 move_next to (0, 28)
# Agent#5 move_next to (29, 30)
# Agent#2 move_next to (8, 16)
# Agent#4 move_next to (8, 16)
# Agent#1 move_next to (12, 15)
# Agent#3 move_next to (8, 16)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (9, 29)
# Agent#3 move_next to (9, 29)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Agent#3 move_next to (0, 14)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:SRLYCV
# Update GameInfo
# Score: 11093.584309366304
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#1 move_next to (0, 28)
# Agent#3 move_next to (17, 4)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#1 move_next to (8, 16)
# Agent#5 move_next to (0, 28)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#5 move_next to (8, 16)
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (24, 17)
# Agent#3 move_next to (0, 28)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (0, 14)
# Update GameInfo
# Score: 11076.756888921902
# Agent#2 move_next to (12, 7)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (8, 16)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (12, 15)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IAJOV
# Agent#3 move_next to (0, 14)
# Agent#1 move_next to (24, 17)
# Update GameInfo
# Score: 11072.96920413158
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (29, 30)
# Agent#2 move_next to (12, 7)
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (29, 30)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (12, 15)
# Update GameInfo
# Score: 11090.237256195283
# Agent#3 move_next to (12, 7)
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (29, 30)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:SRLYCV
# Agent#3 move_next to (12, 15)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#1 move_next to (12, 7)
# Agent#5 move_next to (0, 28)
# Update GameInfo
# Score: 11077.881123033172
# Agent#1 move_next to (29, 30)
# Agent#5 move_next to (8, 16)
# Agent#2 move_next to (0, 28)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (8, 16)
# Agent#4 move_next to (8, 16)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (0, 28)
# Agent#5 move_next to (0, 14)
# Agent#3 move_next to (8, 16)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Update GameInfo
# Score: 11083.808316486029
# Agent#3 move_next to (9, 29)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IAJOV
# Agent#1 move_next to (24, 17)
# Agent#3 move_next to (0, 14)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (0, 28)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (12, 7)
# Update GameInfo
# Score: 11083.845619976186
# Agent#1 move_next to (12, 15)
# Agent#5 move_next to (29, 30)
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (29, 30)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (8, 16)
# Agent#4 move_next to (12, 15)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (9, 29)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IAJOV
# Update GameInfo
# Score: 11083.687317887656
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (29, 30)
# Agent#4 move_next to (12, 7)
# Update GameInfo
# Score: 11087.684848464663
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (12, 7)
# Agent#3 move_next to (0, 28)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (29, 30)
# Agent#4 move_next to (12, 15)
# Agent#3 move_next to (8, 16)
# Agent#2 move_next to (12, 15)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:SRLYCV
# Agent#1 move_next to (24, 17)
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#1 move_next to (29, 30)
# Agent#5 move_next to (0, 28)
# Update GameInfo
# Score: 11089.317281766682
# Agent#3 move_next to (0, 14)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#5 move_next to (8, 16)
# Agent#1 move_next to (12, 15)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (0, 28)
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (9, 29)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#2 move_next to (12, 7)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#4 move_next to (9, 29)
# Agent#2 move_next to (29, 30)
# Update GameInfo
# Score: 11088.084918017732
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (0, 14)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (12, 7)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:SRLYCV
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (29, 30)
# Agent#1 move_next to (29, 30)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#5 move_next to (0, 28)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#3 move_next to (12, 15)
# Update GameInfo
# Score: 11077.08638498046
# Agent#1 move_next to (12, 15)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (8, 16)
# Agent#2 move_next to (0, 28)
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#5 move_next to (0, 14)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (9, 29)
# Agent#3 move_next to (24, 17)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Agent#5 move_next to (17, 4)
# Update GameInfo
# Score: 11086.429457217791
# Agent#3 move_next to (12, 7)
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (29, 30)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:SRLYCV
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#3 move_next to (12, 15)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#5 move_next to (0, 28)
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (8, 16)
# Update GameInfo
# Score: 11086.176667081003
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (8, 16)
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (9, 29)
# Agent#3 move_next to (24, 17)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (9, 29)
# Agent#3 move_next to (12, 7)
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Agent#5 move_next to (17, 4)
# Agent#3 move_next to (29, 30)
# Agent#1 move_next to (29, 30)
# Update GameInfo
# Score: 11085.960520416138
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:SRLYCV
# Agent#1 move_next to (12, 15)
# Agent#3 move_next to (12, 15)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (0, 28)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (8, 16)
# Update GameInfo
# Score: 11079.726597993405
# Agent#3 move_next to (24, 17)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (12, 7)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (9, 29)
# Agent#3 move_next to (12, 7)
# Agent#1 move_next to (8, 16)
# Agent#2 move_next to (29, 30)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (0, 14)
# Agent#3 move_next to (29, 30)
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (12, 15)
# Agent#5 move_next to (17, 4)
# Agent#3 move_next to (12, 15)
# Agent#1 move_next to (0, 14)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IAJOV
# Update GameInfo
# Score: 11089.788047830996
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (0, 28)
# Agent#3 move_next to (24, 17)
# Agent#5 move_next to (12, 7)
# Agent#2 move_next to (8, 16)
# Agent#4 move_next to (8, 16)
# Agent#1 move_next to (24, 17)
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (29, 30)
# Update GameInfo
# Score: 11096.744561068434
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (9, 29)
# Agent#3 move_next to (29, 30)
# Agent#1 move_next to (12, 7)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (12, 15)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#1 move_next to (12, 15)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:SRLYCV
# Agent#2 move_next to (15, 24)
# Agent#1 next task:HYLYJPLYZH
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Update GameInfo
# Score: 11086.220123641286
# Agent#5 move_next to (0, 28)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (1, 10)
# Agent#4 move_next to (24, 17)
# Agent#3 move_next to (0, 28)
# Agent#5 move_next to (8, 16)
# Agent#3 move_next to (8, 16)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (0, 14)
# Agent#2 move_next to (9, 29)
# Update GameInfo
# Score: 11108.236323712303
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (0, 14)
# Agent#5 move_next to (17, 4)
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IAJOV
# Agent#2 move_next to (21, 23)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (0, 28)
# Update GameInfo
# Score: 11089.261279359658
# Agent#4 move_next to (0, 28)
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (8, 16)
# Agent#5 move_next to (29, 30)
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (9, 29)
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (9, 29)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (10, 20)
# Agent#4 move_next to (0, 14)
# Agent#3 move_next to (0, 14)
# Agent#1 move_next to (12, 15)
# Agent#4 move_next to (17, 4)
# Update GameInfo
# Score: 11093.711956070709
# Agent#2 move_next to (1, 10)
# Agent#1 next task:SRLYCV
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:SRLYCV
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#5 move_next to (0, 28)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (8, 16)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (24, 17)
# Agent#1 move_next to (24, 17)
# Update GameInfo
# Score: 11087.98781921815
# Agent#1 move_next to (12, 7)
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (9, 29)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (12, 7)
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (0, 14)
# Agent#3 move_next to (29, 30)
# Agent#1 move_next to (12, 15)
# Agent#5 move_next to (17, 4)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#4 move_next to (0, 14)
# Agent#3 move_next to (12, 15)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (15, 24)
# Agent#4 next task:IAJOV
# Update GameInfo
# Score: 11086.408744785056
# Agent#2 move_next to (24, 17)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#5 move_next to (24, 17)
# Agent#2 move_next to (12, 7)
# Agent#1 move_next to (0, 28)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (8, 16)
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (24, 17)
# Agent#5 move_next to (29, 30)
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (12, 7)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (9, 29)
# Update GameInfo
# Score: 11095.26176895295
# Agent#3 move_next to (29, 30)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (12, 15)
# Agent#1 move_next to (0, 14)
# Agent#3 move_next to (12, 15)
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#5 move_next to (15, 24)
# Agent#4 next task:DUVARNE
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#2 move_next to (12, 7)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (3, 20)
# Update GameInfo
# Score: 11077.973870012389
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (29, 30)
# Agent#5 move_next to (15, 19)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (24, 17)
# Agent#3 move_next to (8, 16)
# Agent#5 move_next to (15, 24)
# Agent#1 move_next to (8, 16)
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (12, 7)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (12, 7)
# Agent#5 move_next to (8, 16)
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (12, 15)
# Update GameInfo
# Score: 11084.898887567348
# Agent#1 move_next to (0, 14)
# Agent#5 move_next to (29, 13)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (25, 9)
# Agent#4 next task:IIMKOQNJA
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (12, 7)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (23, 17)
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (24, 17)
# Agent#1 move_next to (0, 28)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Update GameInfo
# Score: 11079.689613915778
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (12, 7)
# Agent#3 move_next to (12, 7)
# Agent#1 move_next to (8, 16)
# Agent#4 move_next to (29, 30)
# Agent#3 move_next to (29, 30)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#4 move_next to (12, 15)
# Agent#3 move_next to (12, 15)
# Agent#1 move_next to (0, 14)
# Update GameInfo
# Score: 11077.997443238037
# Agent#2 move_next to (0, 28)
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (15, 11)
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (9, 29)
# Agent#5 move_next to (29, 13)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (29, 30)
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (12, 7)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (12, 7)
# Agent#4 next task:IIMKOQNJA
# Update GameInfo
# Score: 11072.564405439893
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (29, 30)
# Agent#1 move_next to (8, 16)
# Agent#4 move_next to (12, 15)
# Agent#5 move_next to (24, 17)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#3 move_next to (12, 15)
# Agent#1 move_next to (9, 29)
# Agent#1 move_next to (0, 14)
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#5 move_next to (23, 17)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Update GameInfo
# Score: 11075.858065176115
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (8, 16)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#4 move_next to (0, 28)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (8, 16)
# Agent#3 move_next to (12, 7)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (29, 30)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (0, 14)
# Update GameInfo
# Score: 11072.167006646097
# Agent#3 move_next to (12, 15)
# Agent#1 move_next to (8, 16)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#4 move_next to (17, 4)
# Agent#1 move_next to (9, 29)
# Agent#5 move_next to (15, 11)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#1 move_next to (0, 14)
# Agent#2 move_next to (0, 28)
# Agent#5 move_next to (29, 13)
# Agent#5 move_next to (29, 30)
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (0, 28)
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (24, 17)
# Update GameInfo
# Score: 11063.95377357646
# Agent#5 move_next to (12, 7)
# Agent#4 next task:IIMKOQNJA
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (12, 7)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (8, 16)
# Agent#3 move_next to (29, 30)
# Agent#5 move_next to (24, 17)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (9, 29)
# Agent#1 move_next to (24, 17)
# Agent#3 move_next to (12, 15)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (0, 14)
# Agent#5 move_next to (23, 17)
# Agent#1 move_next to (12, 7)
# Update GameInfo
# Score: 11077.147238054766
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#4 move_next to (17, 4)
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (0, 28)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (24, 17)
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (8, 16)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Update GameInfo
# Score: 11062.685619659715
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (12, 7)
# Agent#2 move_next to (9, 29)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (15, 11)
# Agent#1 move_next to (8, 16)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (12, 15)
# Agent#2 move_next to (17, 4)
# Agent#5 move_next to (29, 13)
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#5 move_next to (29, 30)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Update GameInfo
# Score: 11053.594827715424
# Agent#1 move_next to (0, 14)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#5 move_next to (12, 7)
# Agent#4 next task:IIMKOQNJA
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (0, 28)
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (24, 17)
# Agent#3 move_next to (8, 16)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (12, 7)
# Agent#4 move_next to (8, 16)
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (9, 29)
# Agent#1 move_next to (0, 28)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (23, 17)
# Update GameInfo
# Score: 11054.086909463218
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#1 move_next to (8, 16)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#1 move_next to (0, 14)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Update GameInfo
# Score: 11041.936621447205
# Agent#3 move_next to (24, 17)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (24, 17)
# Agent#2 move_next to (12, 7)
# Agent#3 move_next to (12, 7)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (29, 30)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (15, 11)
# Agent#3 move_next to (29, 30)
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (29, 30)
# Agent#1 move_next to (24, 17)
# Agent#5 move_next to (29, 13)
# Agent#3 move_next to (12, 15)
# Agent#5 move_next to (29, 30)
# Update GameInfo
# Score: 11034.968766257245
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (12, 7)
# Agent#5 move_next to (12, 7)
# Agent#4 next task:IIMKOQNJA
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#5 move_next to (24, 17)
# Agent#2 move_next to (0, 28)
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (0, 28)
# Update GameInfo
# Score: 11034.016547722777
# Agent#3 move_next to (8, 16)
# Agent#5 move_next to (23, 17)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (8, 16)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (9, 29)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (9, 29)
# Agent#3 move_next to (0, 14)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (0, 14)
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (17, 4)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Update GameInfo
# Score: 11038.675702276812
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (15, 11)
# Agent#2 move_next to (12, 7)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (29, 13)
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (29, 30)
# Update GameInfo
# Score: 11044.381208232575
# Agent#3 move_next to (29, 30)
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (9, 29)
# Agent#1 move_next to (0, 28)
# Agent#5 move_next to (12, 7)
# Agent#4 next task:IIMKOQNJA
# Agent#1 move_next to (8, 16)
# Agent#3 move_next to (12, 15)
# Agent#4 move_next to (0, 14)
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#4 move_next to (17, 4)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#1 move_next to (0, 14)
# Update GameInfo
# Score: 11036.962461313597
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (23, 17)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (8, 16)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (0, 14)
# Update GameInfo
# Score: 11043.542253393929
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Agent#1 move_next to (8, 16)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (12, 15)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#5 move_next to (15, 11)
# Agent#1 move_next to (0, 14)
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Update GameInfo
# Score: 11039.111906463379
# Agent#3 move_next to (0, 28)
# Agent#5 move_next to (29, 13)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (12, 7)
# Agent#5 move_next to (29, 30)
# Agent#4 move_next to (24, 17)
# Agent#3 move_next to (8, 16)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#2 move_next to (29, 30)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (12, 7)
# Agent#4 next task:IIMKOQNJA
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (29, 30)
# Agent#1 move_next to (24, 17)
# Agent#5 move_next to (24, 17)
# Update GameInfo
# Score: 11042.322363302923
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (17, 4)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#5 move_next to (23, 17)
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#2 move_next to (24, 17)
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (3, 0)
# Agent#1 move_next to (12, 15)
# Agent#2 move_next to (12, 7)
# Agent#3 move_next to (24, 17)
# Update GameInfo
# Score: 11045.658788047609
# Agent#4 move_next to (24, 17)
# Agent#2 move_next to (29, 30)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (12, 15)
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (29, 30)
# Agent#3 move_next to (29, 30)
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (0, 28)
# Agent#1 move_next to (8, 16)
# Agent#3 move_next to (12, 15)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#5 move_next to (15, 11)
# Update GameInfo
# Score: 11041.288415085248
# Agent#1 move_next to (9, 29)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (29, 13)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#5 move_next to (29, 30)
# Agent#1 move_next to (0, 14)
# Agent#2 move_next to (12, 7)
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (12, 7)
# Agent#4 next task:CRXAYIYW
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (12, 7)
# Update GameInfo
# Score: 11041.80165135734
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (8, 16)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (17, 4)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (0, 28)
# Agent#3 move_next to (0, 14)
# Agent#5 move_next to (8, 16)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#5 move_next to (21, 0)
# Agent#1 move_next to (8, 16)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (12, 7)
# Update GameInfo
# Score: 11042.030562033804
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (0, 28)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#2 move_next to (8, 16)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (0, 14)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (29, 30)
# Agent#2 move_next to (0, 14)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#3 move_next to (12, 7)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (12, 15)
# Update GameInfo
# Score: 11035.647438137092
# Agent#3 move_next to (29, 30)
# Agent#5 move_next to (11, 11)
# Agent#4 next task:CRXAYIYW
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#3 move_next to (12, 15)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#1 move_next to (8, 16)
# Agent#5 move_next to (17, 4)
# Agent#2 move_next to (0, 28)
# Agent#5 move_next to (8, 16)
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (24, 17)
# Agent#2 move_next to (8, 16)
# Agent#5 move_next to (21, 0)
# Update GameInfo
# Score: 11038.11447628012
# Agent#1 move_next to (0, 14)
# Agent#4 move_next to (12, 7)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (17, 4)
# Agent#3 move_next to (8, 16)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#3 move_next to (9, 29)
# Agent#5 move_next to (0, 14)
# Agent#2 move_next to (17, 4)
# Agent#5 move_next to (24, 17)
# Agent#3 move_next to (0, 14)
# Update GameInfo
# Score: 11025.786909242279
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (0, 14)
# Agent#3 move_next to (17, 4)
# Agent#1 move_next to (8, 16)
# Agent#2 move_next to (0, 28)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (11, 11)
# Agent#4 next task:CRXAYIYW
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (8, 16)
# Agent#4 move_next to (29, 30)
# Agent#1 move_next to (0, 14)
# Agent#3 move_next to (0, 28)
# Update GameInfo
# Score: 11028.152641279607
# Agent#5 move_next to (17, 4)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (12, 15)
# Agent#1 move_next to (17, 4)
# Agent#3 move_next to (8, 16)
# Agent#5 move_next to (8, 16)
# Agent#5 move_next to (21, 0)
# Agent#2 move_next to (0, 14)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (9, 29)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (12, 7)
# Agent#3 move_next to (0, 14)
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Update GameInfo
# Score: 11022.233275505605
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (12, 7)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (24, 17)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#1 move_next to (29, 30)
# Agent#4 move_next to (29, 30)
# Agent#5 move_next to (0, 14)
# Agent#2 move_next to (12, 7)
# Agent#1 move_next to (12, 15)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (12, 15)
# Agent#2 move_next to (29, 30)
# Agent#5 move_next to (11, 11)
# Agent#4 next task:CRXAYIYW
# Update GameInfo
# Score: 11020.548085054996
# Agent#3 move_next to (8, 16)
# Agent#2 move_next to (12, 15)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#3 move_next to (9, 29)
# Agent#5 move_next to (17, 4)
# Agent#5 move_next to (8, 16)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:SRLYCV
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (21, 0)
# Agent#1 move_next to (8, 16)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (12, 7)
# Update GameInfo
# Score: 11027.916824887747
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (29, 30)
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#2 move_next to (8, 16)
# Agent#1 move_next to (0, 14)
# Agent#4 move_next to (12, 15)
# Agent#5 move_next to (0, 14)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (0, 28)
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#3 move_next to (8, 16)
# Update GameInfo
# Score: 11029.264573133994
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (9, 29)
# Agent#1 move_next to (0, 28)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (11, 11)
# Agent#4 next task:CRXAYIYW
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (8, 16)
# Agent#1 move_next to (8, 16)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (17, 4)
# Agent#5 move_next to (8, 16)
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (0, 14)
# Update GameInfo
# Score: 11031.270624281497
# Agent#2 move_next to (12, 7)
# Agent#5 move_next to (21, 0)
# Agent#1 move_next to (0, 14)
# Agent#4 move_next to (17, 4)
# Agent#2 move_next to (29, 30)
# Agent#3 move_next to (24, 17)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (12, 15)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (29, 30)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (24, 17)
# Update GameInfo
# Score: 11028.25168624236
# Agent#1 move_next to (24, 17)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#3 move_next to (12, 15)
# Agent#5 move_next to (0, 14)
# Agent#4 move_next to (8, 16)
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (11, 11)
# Agent#4 next task:CRXAYIYW
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (12, 7)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (0, 14)
# Agent#2 move_next to (29, 30)
# Agent#1 move_next to (12, 15)
# Agent#4 move_next to (17, 4)
# Update GameInfo
# Score: 11027.869222861542
# Agent#3 move_next to (24, 17)
# Agent#5 move_next to (17, 4)
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (8, 16)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#5 move_next to (21, 0)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (29, 30)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (12, 7)
# Agent#3 move_next to (12, 15)
# Agent#1 move_next to (24, 17)
# Update GameInfo
# Score: 11028.113443014725
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (0, 14)
# Agent#2 move_next to (12, 7)
# Agent#1 move_next to (29, 30)
# Agent#3 move_next to (15, 24)
# Agent#2 next task:IAJOV
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (24, 17)
# Agent#2 move_next to (29, 30)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (12, 15)
# Agent#4 move_next to (0, 14)
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (17, 4)
# Agent#3 move_next to (12, 7)
# Update GameInfo
# Score: 11028.616301541906
# Agent#5 move_next to (11, 11)
# Agent#4 next task:CRXAYIYW
# Agent#1 move_next to (15, 24)
# Agent#0 next task:IAJOV
# Agent#3 move_next to (29, 30)
# Agent#4 move_next to (15, 24)
# Agent#3 next task:SRLYCV
# Agent#2 move_next to (15, 24)
# Agent#1 next task:IAJOV
# Agent#3 move_next to (12, 15)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (24, 17)
# Agent#4 move_next to (0, 28)
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (24, 17)
# Agent#5 move_next to (8, 16)
# Agent#1 move_next to (29, 30)
# Agent#2 move_next to (12, 7)
# Agent#5 move_next to (21, 0)
# Update GameInfo
# Score: 11030.83857590301
# Agent#3 move_next to (15, 24)
# Agent#2 next task:SRLYCV
# Agent#4 move_next to (8, 16)
# Agent#2 move_next to (29, 30)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (12, 15)
# Agent#4 move_next to (9, 29)
# Agent#2 move_next to (12, 15)
# Agent#3 move_next to (0, 28)
# Agent#3 move_next to (8, 16)
# Agent#4 move_next to (0, 14)
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (15, 24)
# Agent#0 next task:SRLYCV
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (24, 17)
# Agent#3 move_next to (9, 29)
# Agent#2 move_next to (15, 24)
# Agent#1 next task:GKMXMQ
# Update GameInfo
# Score: 11024.7446154381
# Agent#4 move_next to (15, 24)
# Agent#3 next task:IAJOV
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (0, 28)
# Agent#3 move_next to (0, 14)
# Agent#1 move_next to (8, 16)
# Agent#2 move_next to (28, 18)
# Agent#3 move_next to (17, 4)
# ...
# Agent#0 next task:BAZUAW
# Agent#3 move_next to (9, 29)
# Agent#5 move_next to (9, 29)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (5, 24)
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (10, 20)
# Agent#1 move_next to (12, 7)
# Agent#5 move_next to (21, 0)
# Agent#2 move_next to (21, 0)
# Agent#3 move_next to (10, 20)
# Agent#1 move_next to (10, 20)
# Agent#5 move_next to (0, 28)
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (15, 19)
# Agent#3 move_next to (1, 10)
# Agent#2 next task:BAYQHW
# Agent#4 move_next to (12, 7)
# Update GameInfo
# Score: 12006.349920289787
# Agent#1 move_next to (15, 19)
# Agent#3 move_next to (5, 24)
# Agent#4 move_next to (11, 11)
# Agent#3 next task:LXSCR
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (12, 7)
# Agent#4 move_next to (9, 29)
# Agent#1 move_next to (11, 11)
# Agent#0 next task:BAZUAW
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (21, 0)
# Agent#1 move_next to (5, 24)
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (8, 16)
# Agent#4 next task:BAZUAW
# Agent#1 move_next to (10, 20)
# Agent#3 move_next to (15, 11)
# Update GameInfo
# Score: 12002.991760405957
# Agent#2 move_next to (8, 16)
# Agent#1 next task:LXSCR
# Agent#1 move_next to (15, 19)
# Agent#3 move_next to (1, 10)
# Agent#4 move_next to (17, 4)
# Agent#3 move_next to (11, 11)
# Agent#2 next task:LXSCR
# Agent#5 move_next to (5, 24)
# Agent#1 move_next to (12, 7)
# Agent#1 move_next to (11, 11)
# Agent#0 next task:BAZUAW
# Agent#2 move_next to (9, 29)
# Agent#5 move_next to (12, 7)
# Agent#3 move_next to (9, 29)
# Agent#1 move_next to (5, 24)
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (21, 0)
# Agent#5 move_next to (10, 20)
# Update GameInfo
# Score: 12002.630168025918
# Agent#3 move_next to (21, 0)
# Agent#4 move_next to (8, 16)
# Agent#3 next task:LXSCR
# Agent#2 move_next to (0, 28)
# Agent#1 move_next to (10, 20)
# Agent#3 move_next to (0, 28)
# Agent#5 move_next to (15, 19)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (15, 19)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (11, 11)
# Agent#4 next task:LXSCR
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (21, 0)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (12, 7)
# Agent#1 move_next to (11, 11)
# Agent#0 next task:LXSCR
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (21, 0)
# Agent#4 move_next to (0, 28)
# Update GameInfo
# Score: 11997.080126105384
# Agent#1 move_next to (9, 29)
# Agent#1 move_next to (21, 0)
# Agent#5 move_next to (0, 28)
# Agent#2 move_next to (8, 16)
# Agent#1 next task:LXSCR
# Agent#3 move_next to (8, 16)
# Agent#2 next task:LXSCR
# Agent#1 move_next to (0, 28)
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (17, 4)
# Agent#2 move_next to (9, 29)
# Update GameInfo
# Score: 11984.302271093633
# Agent#3 move_next to (9, 29)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (21, 0)
# Agent#3 move_next to (21, 0)
# Agent#4 move_next to (8, 16)
# Agent#3 next task:BAZUAW
# Agent#2 move_next to (0, 28)
# Agent#5 move_next to (8, 16)
# Agent#4 next task:BAZUAW
# Agent#3 move_next to (0, 28)
# Agent#1 move_next to (8, 16)
# Agent#0 next task:BAZUAW
# Agent#4 move_next to (5, 24)
# Agent#5 move_next to (5, 24)
# Agent#2 move_next to (17, 4)
# Update GameInfo
# Score: 11990.939416992233
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (12, 7)
# Agent#4 move_next to (10, 20)
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (5, 24)
# Agent#5 move_next to (10, 20)
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (8, 16)
# Agent#1 next task:LXSCR
# Agent#4 move_next to (15, 19)
# Agent#5 move_next to (15, 19)
# Agent#1 move_next to (10, 20)
# Agent#3 move_next to (8, 16)
# Agent#2 next task:LXSCR
# Agent#4 move_next to (12, 7)
# Agent#4 move_next to (11, 11)
# Agent#3 next task:LXSCR
# Agent#5 move_next to (12, 7)
# Update GameInfo
# Score: 11986.518181245467
# Agent#5 move_next to (11, 11)
# Agent#4 next task:DUVARNE
# Agent#1 move_next to (15, 19)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (9, 29)
# Agent#4 move_next to (21, 0)
# Agent#3 move_next to (9, 29)
# Agent#5 move_next to (3, 20)
# Agent#5 move_next to (15, 19)
# Agent#1 move_next to (12, 7)
# Agent#1 move_next to (11, 11)
# Agent#0 next task:LXSCR
# Agent#2 move_next to (21, 0)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (15, 24)
# Agent#2 move_next to (0, 28)
# Agent#3 move_next to (21, 0)
# Agent#1 move_next to (9, 29)
# Agent#1 move_next to (21, 0)
# Agent#3 move_next to (0, 28)
# Agent#5 move_next to (12, 7)
# Agent#5 move_next to (8, 16)
# Update GameInfo
# Score: 11991.009409137729
# Agent#1 move_next to (0, 28)
# Agent#4 move_next to (17, 4)
# Agent#2 move_next to (17, 4)
# Agent#5 move_next to (29, 13)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (25, 9)
# Agent#4 next task:INKKLX
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (8, 16)
# Agent#3 next task:BAZUAW
# Agent#2 move_next to (8, 16)
# Agent#1 next task:BAZUAW
# Agent#5 move_next to (24, 17)
# Agent#5 move_next to (29, 13)
# Update GameInfo
# Score: 11985.748721447027
# Agent#3 move_next to (8, 16)
# Agent#2 next task:LXSCR
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (29, 6)
# Agent#4 move_next to (5, 24)
# Agent#5 move_next to (30, 6)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (8, 16)
# Agent#0 next task:LXSCR
# Agent#2 move_next to (5, 24)
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (12, 7)
# Agent#2 move_next to (12, 7)
# Agent#4 move_next to (10, 20)
# Agent#2 move_next to (10, 20)
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (21, 0)
# Agent#5 move_next to (21, 0)
# Agent#4 next task:GKMXMQ
# Agent#5 move_next to (28, 18)
# Update GameInfo
# Score: 11993.181019866675
# Agent#1 move_next to (21, 0)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (15, 19)
# Agent#2 move_next to (15, 19)
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (12, 7)
# Agent#4 move_next to (11, 11)
# Agent#3 next task:LXSCR
# Agent#2 move_next to (11, 11)
# Agent#1 next task:LXSCR
# Agent#5 move_next to (30, 6)
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (9, 29)
# Agent#2 move_next to (9, 29)
# Agent#2 move_next to (21, 0)
# Agent#4 move_next to (21, 0)
# Agent#5 move_next to (3, 0)
# Update GameInfo
# Score: 11992.057481788155
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (0, 28)
# Agent#2 move_next to (0, 28)
# Agent#5 move_next to (21, 0)
# Agent#3 move_next to (8, 16)
# Agent#2 next task:LXSCR
# Agent#1 move_next to (8, 16)
# Agent#0 next task:LXSCR
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (3, 0)
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (9, 29)
# Update GameInfo
# Score: 11981.53774860257
# Agent#5 move_next to (15, 11)
# Agent#4 next task:LXSCR
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (21, 0)
# Agent#4 move_next to (8, 16)
# Agent#3 next task:BAZUAW
# Agent#5 move_next to (9, 29)
# Agent#2 move_next to (8, 16)
# Agent#1 next task:BAZUAW
# Agent#3 move_next to (0, 28)
# Agent#1 move_next to (21, 0)
# Agent#5 move_next to (21, 0)
# Agent#1 move_next to (0, 28)
# Agent#4 move_next to (5, 24)
# Agent#2 move_next to (5, 24)
# Update GameInfo
# Score: 11982.1506970833
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (0, 28)
# Agent#4 move_next to (12, 7)
# Agent#2 move_next to (12, 7)
# Agent#1 move_next to (17, 4)
# Agent#4 move_next to (10, 20)
# Agent#2 move_next to (10, 20)
# Agent#3 move_next to (8, 16)
# Agent#2 next task:LXSCR
# Agent#4 move_next to (15, 19)
# Agent#5 move_next to (17, 4)
# Agent#2 move_next to (15, 19)
# Agent#1 move_next to (8, 16)
# Agent#0 next task:BAZUAW
# Agent#4 move_next to (12, 7)
# Agent#4 move_next to (11, 11)
# Agent#3 next task:LXSCR
# Update GameInfo
# Score: 11974.30109252567
# Agent#2 move_next to (12, 7)
# Agent#2 move_next to (11, 11)
# Agent#1 next task:LXSCR
# Agent#3 move_next to (9, 29)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (8, 16)
# Agent#4 next task:LXSCR
# Agent#4 move_next to (21, 0)
# Agent#2 move_next to (9, 29)
# Agent#2 move_next to (21, 0)
# Agent#1 move_next to (5, 24)
# Agent#3 move_next to (21, 0)
# Agent#4 move_next to (0, 28)
# Agent#1 move_next to (12, 7)
# Agent#3 move_next to (0, 28)
# Agent#2 move_next to (0, 28)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (10, 20)
# Update GameInfo
# Score: 11981.967535144315
# Agent#5 move_next to (21, 0)
# Agent#4 move_next to (17, 4)
# Agent#1 move_next to (15, 19)
# Agent#3 move_next to (17, 4)
# Agent#5 move_next to (0, 28)
# Agent#2 move_next to (17, 4)
# Agent#1 move_next to (12, 7)
# Agent#1 move_next to (11, 11)
# Agent#0 next task:LXSCR
# Agent#1 move_next to (9, 29)
# Agent#1 move_next to (21, 0)
# Agent#3 move_next to (8, 16)
# Agent#2 next task:BAZUAW
# Agent#4 move_next to (8, 16)
# Agent#3 next task:LXSCR
# Agent#5 move_next to (17, 4)
# Update GameInfo
# Score: 11966.435549593205
# Agent#2 move_next to (8, 16)
# Agent#1 next task:XAYIYW
# Agent#1 move_next to (0, 28)
# Agent#3 move_next to (5, 24)
# Agent#4 move_next to (9, 29)
# Agent#2 move_next to (21, 0)
# Agent#5 move_next to (8, 16)
# Agent#4 next task:LXSCR
# Agent#4 move_next to (21, 0)
# Agent#3 move_next to (12, 7)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (12, 7)
# Agent#3 move_next to (10, 20)
# Agent#4 move_next to (0, 28)
# Update GameInfo
# Score: 11969.161809754627
# Agent#5 move_next to (9, 29)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (15, 19)
# Agent#5 move_next to (21, 0)
# Agent#1 move_next to (8, 16)
# Agent#0 next task:LXSCR
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (12, 7)
# Agent#3 move_next to (11, 11)
# Agent#2 next task:LXSCR
# Agent#4 move_next to (17, 4)
# Agent#5 move_next to (0, 28)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (9, 29)
# Agent#3 move_next to (21, 0)
# Update GameInfo
# Score: 11963.447505234499
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (11, 11)
# Agent#1 next task:LXSCR
# Agent#4 move_next to (8, 16)
# Agent#3 next task:LXSCR
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (21, 0)
# Agent#3 move_next to (0, 28)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (9, 29)
# Agent#4 move_next to (9, 29)
# Agent#2 move_next to (21, 0)
# Agent#5 move_next to (8, 16)
# Agent#4 next task:XAYIYW
# Agent#3 move_next to (17, 4)
# Agent#4 move_next to (21, 0)
# Update GameInfo
# Score: 11972.17522235164
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (21, 0)
# Agent#3 move_next to (8, 16)
# Agent#2 next task:XAYIYW
# Agent#5 move_next to (12, 7)
# Agent#1 move_next to (8, 16)
# Agent#0 next task:LXSCR
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Update GameInfo
# Score: 11964.332799258938
# Agent#3 move_next to (21, 0)
# Agent#5 move_next to (0, 14)
# Agent#5 move_next to (24, 17)
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (12, 7)
# Agent#2 move_next to (8, 16)
# Agent#1 next task:LXSCR
# Agent#4 move_next to (8, 16)
# Agent#3 next task:LXSCR
# Agent#5 move_next to (0, 14)
# Agent#1 move_next to (21, 0)
# Agent#3 move_next to (0, 14)
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (24, 17)
# Agent#4 move_next to (9, 29)
# Agent#5 move_next to (11, 11)
# Agent#4 next task:LXSCR
# Update GameInfo
# Score: 11959.844950235632
# Agent#2 move_next to (21, 0)
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (21, 0)
# Agent#1 move_next to (17, 4)
# Agent#5 move_next to (9, 29)
# Agent#2 move_next to (0, 28)
# Agent#4 move_next to (0, 28)
# Agent#5 move_next to (21, 0)
# Agent#3 move_next to (11, 11)
# Agent#2 next task:BAZUAW
# Agent#5 move_next to (0, 28)
# Update GameInfo
# Score: 11965.835679933614
# Agent#1 move_next to (8, 16)
# Agent#0 next task:LXSCR
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (5, 24)
# Agent#4 move_next to (17, 4)
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (10, 20)
# Agent#2 move_next to (8, 16)
# Agent#1 next task:LXSCR
# Agent#4 move_next to (8, 16)
# Agent#3 next task:LXSCR
# Agent#1 move_next to (21, 0)
# Agent#3 move_next to (15, 19)
# Update GameInfo
# Score: 11959.798202385853
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (9, 29)
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (8, 16)
# Agent#4 next task:LXSCR
# Agent#3 move_next to (11, 11)
# Agent#2 next task:BAZUAW
# Agent#4 move_next to (9, 29)
# Agent#2 move_next to (21, 0)
# Agent#3 move_next to (5, 24)
# Agent#3 move_next to (12, 7)
# Agent#4 move_next to (21, 0)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (0, 28)
# Agent#5 move_next to (9, 29)
# Agent#3 move_next to (10, 20)
# Agent#4 move_next to (0, 28)
# Update GameInfo
# Score: 11964.52091863095
# Agent#5 move_next to (21, 0)
# Agent#3 move_next to (15, 19)
# Agent#5 move_next to (0, 28)
# Agent#1 move_next to (8, 16)
# Agent#0 next task:LXSCR
# Agent#2 move_next to (17, 4)
# Agent#3 move_next to (12, 7)
# Agent#4 move_next to (17, 4)
# Agent#3 move_next to (11, 11)
# Agent#2 next task:BAZUAW
# Agent#3 move_next to (5, 24)
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (9, 29)
# Agent#2 move_next to (8, 16)
# Agent#1 next task:XAYIYW
# Update GameInfo
# Score: 11955.92760542113
# Agent#3 move_next to (10, 20)
# Agent#4 move_next to (8, 16)
# Agent#3 next task:XAYIYW
# Agent#1 move_next to (21, 0)
# Agent#1 move_next to (0, 28)
# Agent#3 move_next to (15, 19)
# Agent#5 move_next to (8, 16)
# Agent#4 next task:LXSCR
# Agent#2 move_next to (21, 0)
# Agent#4 move_next to (21, 0)
# Agent#3 move_next to (12, 7)
# Agent#2 move_next to (12, 7)
# Agent#3 move_next to (11, 11)
# Agent#2 next task:AMSPFVQ
# Agent#4 move_next to (12, 7)
# Agent#1 move_next to (17, 4)
# Agent#3 move_next to (12, 7)
# Agent#5 move_next to (9, 29)
# Update GameInfo
# Score: 11964.789007862395
# Agent#3 move_next to (3, 0)
# Agent#2 move_next to (0, 14)
# Agent#3 move_next to (0, 28)
# Agent#4 move_next to (0, 14)
# Agent#5 move_next to (21, 0)
# Agent#2 move_next to (24, 17)
# Agent#3 move_next to (21, 23)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (0, 28)
# Agent#1 move_next to (8, 16)
# Agent#0 next task:XAYIYW
# Agent#2 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Agent#3 move_next to (7, 5)
# Update GameInfo
# Score: 11957.284143667088
# Agent#2 move_next to (11, 11)
# Agent#1 next task:CRXAYIYW
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (21, 0)
# Agent#4 move_next to (11, 11)
# Agent#3 next task:CRXAYIYW
# Agent#3 move_next to (15, 24)
# Agent#1 move_next to (12, 7)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Agent#2 move_next to (8, 16)
# Agent#3 move_next to (15, 11)
# Agent#2 next task:CRXAYIYW
# Agent#5 move_next to (8, 16)
# Agent#4 next task:LXSCR
# Agent#1 move_next to (0, 14)
# Agent#4 move_next to (8, 16)
# Agent#2 move_next to (21, 0)
# Update GameInfo
# Score: 11954.60430568254
# Agent#1 move_next to (24, 17)
# Agent#4 move_next to (21, 0)
# Agent#3 move_next to (17, 4)
# Agent#2 move_next to (12, 7)
# Agent#4 move_next to (12, 7)
# Agent#5 move_next to (9, 29)
# Agent#1 move_next to (0, 14)
# Agent#3 move_next to (8, 16)
# Agent#3 move_next to (21, 0)
# Agent#2 move_next to (0, 14)
# Agent#5 move_next to (21, 0)
# Agent#4 move_next to (0, 14)
# Agent#1 move_next to (11, 11)
# Agent#0 next task:LXSCR
# Agent#3 move_next to (12, 7)
# Agent#2 move_next to (24, 17)
# Agent#4 move_next to (24, 17)
# Agent#5 move_next to (0, 28)
# Update GameInfo
# Score: 11947.317813981783
# Agent#2 move_next to (0, 14)
# Agent#1 move_next to (9, 29)
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (0, 14)
# Agent#3 move_next to (24, 17)
# Agent#5 move_next to (17, 4)
# Agent#1 move_next to (21, 0)
# Agent#2 move_next to (11, 11)
# Agent#1 next task:CRXAYIYW
# Agent#3 move_next to (0, 14)
# Agent#4 move_next to (11, 11)
# Agent#3 next task:CRXAYIYW
# Agent#1 move_next to (0, 28)
# Agent#2 move_next to (17, 4)
# Agent#4 move_next to (17, 4)
# Update GameInfo
# Score: 11936.354097536476
# Agent#3 move_next to (11, 11)
# Agent#2 next task:LXSCR
# Agent#3 move_next to (9, 29)
# Agent#5 move_next to (8, 16)
# Agent#4 next task:LXSCR
# Agent#2 move_next to (8, 16)
# Agent#1 move_next to (17, 4)
# Agent#2 move_next to (21, 0)
# Agent#3 move_next to (21, 0)
# Agent#4 move_next to (8, 16)
# Agent#5 move_next to (9, 29)
# Agent#5 move_next to (21, 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-41230396c3bd> in <module>
#       1 bot = Bot()
# ----> 2 bot.solve()
#
# <ipython-input-9-64a9f44f78e1> in solve(self)
#     204                 print("Score: {}".format(self.get_now_score()))
#     205
# --> 206             time.sleep(0.5)
#
# KeyboardInterrupt:

# %%
random.random()
# Out:
# 0.9575105958911774
